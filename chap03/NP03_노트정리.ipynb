# %% [markdown]
# ## 3장 노트정리
#
# 이파일은 3장 학습하면서 실행한 내용을 정리한 것이다.
#
# 날짜 : 2025.09.17
#
# 저자: 김아영 학번: 202311394

# %% [markdown]
# # 프로그램 제어문
#
# 프로그램은 작성 순서대로 실행
#
# 제어문: 프로그램의 실행 순서를 바꾸는 문장
#
# 조건문: if-else, if-elif-else
#
# 반복문: while, for
#
# 기타 제어문: break continue

# %%
# 조건문 if문

score = int(input("정수 입력:"))
if score >= 90 : #if문 끝에 :을 붙인다
    print("성적 : A") #들여쓰기
    print("장학금 수여")

# %%
# 조건문 if문
age_0 = 22
age_1 = 18
age = int(input('your age? '))
if age < age_0 and age > age_1: #복합 조건문
    print("당신의 나이는 18~22세 사이입니다")
# Out:
# 당신의 나이는 18~22세 사이입니다

# %%
#if-else문
if score >= 90 :
    print("pass")
else : #else도 끝에 :을 붙인다
    print("fail") #들여쓰기
# Out:
# fail

# %%
# 한줄로 표현하기
res = 'pass' if score >= 90 else 'fail'
print(res)
# Out:
# fail

# %%
# 조건문 예제
year = int(input("Type a year :"))
if (year%4 == 0 and year%100 != 0) or (year%400) == 0 :
    print(year, "is a leap year")
else :
    print(year, "is not a leap year")
# Out:
# 11 is not a leap year

# %%
#조건문(중첩 if문- if 문 속에 또 다른 if문)
n = int(input("type int number : "))
if n > 0 :
    print("positive")
else:
    if n < 0 :
        print("negative")
    else:
        print("0")
        n = int(input("type int number : "))
    if n >= 0 :
        if n == 0 :
            print("0")
        else:
            print("positive")
    else:
        print("negative")
# Out:
# positive

# %% [markdown]
# # if-elif-else 문
# if 조건1이 참이면 블록1, if 조건1이 거짓이고 elif 조건2이 참이면 블록2, 조건이 모두 거짓이면
# 블록3이 실행된다

# %%
#조건문(if-elif-else문)
n = int(input("type int number : "))
if n > 0 :
    print("positive")
elif n < 0 :
    print("negative")
else :
    print("0")
# Out:
# positive

# %%
# 조건문(다중 elif문)
age = 12
if age < 4:
    price = 0
elif age < 18:
    price = 5
elif age < 65:
    price = 10
else:
    price = 5
print("Your admission cost is $" + str(price) + ".")
# Out:
# Your admission cost is $5.

# %% [markdown]
# # 반복문
# 조건이 충족되면 동일한 일을 반복 수행

# %%
i = 1 #초기화
sum = 0
while i <= 100 : #조건 판단. 끝에 :를 붙인다
    sum = sum + i#블록
    i = i + 1 #조건 변경
    
print("sum=", sum) #블록이 끝나면 다시 들여쓰기를 원래 위치로
# Out:
# sum= 5050

# %%
# while 연습문제
#10진수를 입력 받아 2진수로 변환하여 출력하기
n = int(input('Number: '))
result = '' #변환 결과 저장
#10진수를 2로 나누어 몫이 0이 될 때까지 반복해서 나머지를 구한다
while n != 0:
    m = n % 2 #나머지
    result = str(m) + result #숫자를 문자열로 변환
    n = n // 2 #몫
print("2진수 =", result)
# Out:
# 2진수 = 1010

# %% [markdown]
# # 반복문
# for문
# • [반복객체]의 각 요소의 값을 하나씩 [변수]에 저장하고 블록을 실행
#
# • [반복객체]에 더 이상의 요소가 없을 때까지 반복
#
#     for i in [1, 2, 3] : #끝에 :를 붙인다
#
#         print("숫자", i)
#
# • 튜플, 문자열과 같은 반복 객체를 사용할 수도 있다.

# %%
# 반복문(for문)
for i in (1, 2, 3):
    print("숫자", i)
for i in 'hello':
    print(i)
# Out:
# 숫자 1
# 숫자 2
# 숫자 3
# h
# e
# l
# l
# o

# %%
#반복문(for-range문)
for i in range(1, 4, 1) : #1부터 시작하여 1씩 증가하여 4가 되면 종료
    print("Number", i)
# Out:
# Number 1
# Number 2
# Number 3

# %%
# 반복문
# for 문을 이용한 1부터 100까지의 합 구하기
sum = 0
for i in range(1, 101, 1) :
    sum = sum + i
print("sum = ", sum)
# Out:
# sum =  5050

# %%
# x ^ n을 구하는 프로그램

x = float(input('Type x : '))
n = int(input('Type n : '))
prod = 1
for i in range(1, n+1):
    prod = prod * x
print(prod)
# Out:
# 625.0

# %% [markdown]
# # 중첩 반복문
# • 내부 for 문이 먼저 실행되고 끝나면 외부 for 문이 실행됨

# %%
#중첩 반복문(구구단 프로그램)
for i in range(2, 10, 1) :
    for j in range(1, 10, 1):
        print("%d x %d = %d" %(i, j, i*j))
# Out:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81

# %%
# 무한 반복문
while True : #조건이 항상 참이다
    print("last forever")
# Out:
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# ...
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# last forever
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 # 무한 반복문
#       2 while True : #조건이 항상 참이다
# ----> 3     print("last forever")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:3045, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3043 def write(data, *args, **kwargs):
#    3044     """Write data to both the original destination and the capture dictionary."""
# -> 3045     result = original_write(data, *args, **kwargs)
#    3046     if any(
#    3047         [
#    3048             self.display_pub.is_publishing,
#    (...)   3051         ]
#    3052     ):
#    3053         return result
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\iostream.py:681, in OutStream.write(self, string)
#     678     msg = "I/O operation on closed file"
#     679     raise ValueError(msg)
# --> 681 is_child = not self._is_master_process()
#     682 # only touch the buffer in the IO thread to avoid races
#     683 with self._buffer_lock:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\iostream.py:551, in OutStream._is_master_process(self)
#     550 def _is_master_process(self):
# --> 551     return os.getpid() == self._master_pid
#
# KeyboardInterrupt:

# %%
#제어문 예제(반복문 안의 조건문)
#숫자 맞추기 게임 프로그램
## 1~100 사이의 난수를 만들고 사용자가 1~100 사이의 수를 입력하여 맞추는 프로그램. 5회까지
## 맞추지 못하면 종료

from random import randint
secret_num = randint(1,100)
num_guesses = 0 #시도 회수
guess = 0 #예상 숫자
while guess != secret_num and num_guesses <= 4:
    guess = eval(input('Enter your guess (1-100): ')) #수 입력
    num_guesses = num_guesses + 1 #시도 횟수 증가
    if guess < secret_num: #정답이 클 때
        print('더 큽니다.', 5-num_guesses, '회 남았습니다.\n')
    elif guess > secret_num: #정답이 작을 때
        print('더 작습니다.', 5-num_guesses, '회 남았습니다.\n')
    else: #정답
        print('맞았습니다!')
if num_guesses==5 and guess != secret_num: #맞추지 못한 경우
    print('당신이 졌습니다. 정답은 ', secret_num, '입니다')
# Out:
# 더 큽니다. 4 회 남았습니다.
#
# 더 작습니다. 3 회 남았습니다.
#
# 더 큽니다. 2 회 남았습니다.
#
# 더 작습니다. 1 회 남았습니다.
#
# 더 작습니다. 0 회 남았습니다.
#
# 당신이 졌습니다. 정답은  56 입니다

# %%
# 기타 제어문
# break 문
# 반복문을 빠져나올 때 사용
n = 10
while n >= -10 :
    if n == 0 :
        break #n=0이면 while 블록을 빠져나온다
    inv = 1.0 / n
    print(inv)
    n = n - 1
# Out:
# 0.1
# 0.1111111111111111
# 0.125
# 0.14285714285714285
# 0.16666666666666666
# 0.2
# 0.25
# 0.3333333333333333
# 0.5
# 1.0

# %%
#continue 문
# 블록의 나머지 부분은 생략하고 다시 while 조건 조사
n = 10
while n >= -10 :
    if n == 0 :
        n = n - 1
        continue #n=0이면 while 블록의 나머지 부분을 건너 뛴다
    inv = 1.0 / n
    print("n = %d, inv(n) = %0.2f"%(n, inv))
    n = n-1
# Out:
# n = 10, inv(n) = 0.10
# n = 9, inv(n) = 0.11
# n = 8, inv(n) = 0.12
# n = 7, inv(n) = 0.14
# n = 6, inv(n) = 0.17
# n = 5, inv(n) = 0.20
# n = 4, inv(n) = 0.25
# n = 3, inv(n) = 0.33
# n = 2, inv(n) = 0.50
# n = 1, inv(n) = 1.00
# n = -1, inv(n) = -1.00
# n = -2, inv(n) = -0.50
# n = -3, inv(n) = -0.33
# n = -4, inv(n) = -0.25
# n = -5, inv(n) = -0.20
# n = -6, inv(n) = -0.17
# n = -7, inv(n) = -0.14
# n = -8, inv(n) = -0.12
# n = -9, inv(n) = -0.11
# n = -10, inv(n) = -0.10

# %%
#match문
# Python 3.10 이상에서 실행 가능
def handle_status(status):
    match status:
        case 200:
            return "성공"
        case 404:
            return "페이지를 찾을 수 없음"
        case 500:
            return "서버 오류"
        case _:   # default case (와일드카드)
            return "알 수 없는 상태"

# 실행 예제
print(handle_status(200))   # 성공
print(handle_status(404))   # 페이지를 찾을 수 없음
print(handle_status(500))   # 서버 오류
print(handle_status(999))   # 알 수 없는 상태
# Out:
# 성공
# 페이지를 찾을 수 없음
# 서버 오류
# 알 수 없는 상태
